# %%
import pandas as pd

# %%
df1=pd.read_csv("C:/Users/nhm/Downloads/SEM.csv")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SNO     60 non-null     int64
#  1   REG_NO  60 non-null     object
#  2   NAME    60 non-null     object
#  3   DM      59 non-null     object
#  4   FLA     59 non-null     object
#  5   CN      58 non-null     object
#  6   BD      59 non-null     object
#  7   CC      59 non-null     object
#  8   CC.1    35 non-null     object
#  9   CNS     13 non-null     object
#  10  FS      11 non-null     object
#  11  SRWC    59 non-null     object
# dtypes: int64(1), object(11)
# memory usage: 5.8+ KB

# %%
grade_points={'O':10,'A+':9,'A':8,'B+':7,'B':6,'C':5,'F':0}

# %%
df1['DM_pt']=df1['DM'].map(grade_points)*4
df1['FLA_pt']=df1['FLA'].map(grade_points)*3
df1['CN_pt']=df1['CC'].map(grade_points)*4
df1['BD_pt']=df1['BD'].map(grade_points)*3
df1['COMM_pt']=df1['COMM'].map(grade_points)*1
df1['CC_pt']=df1['CC.1'].map(grade_points)*3
df1['CNS_pt']=df1['CNS'].map(grade_points)*3
df1['FS_pt']=df1['FS'].map(grade_points)*3
df1['SRWC_pt']=df1['SRWC'].map(grade_points)*3

# %%
columns=['DM_pt','FLA_pt','CN_pt','BD_pt','COMM_pt','CC_pt','CNS_pt','FS_pt','SRWC_pt']

# %%
df1.fillna(0,inplace=True)

# %%
total_credits=21

# %%
df1['SGPA']=df1[columns].sum(axis=1)/total_credits

# %%
df1
# Out:
#     SNO           REG_NO                            NAME  DM FLA  CC  BD COMM  \
# 0     1  RA2211008020061                 SUJITHRA DEVI M  A+   A  A+   O    O
# 1     2  RA2211008020062                         VARUN R   A  B+   A   A    o
# 2     3  RA2211008020063                MOHAMMED AASIF A  A+   A  A+  A+    O
# 3     4  RA2211008020064                      NAVEEN VBR  A+  B+  A+   O    O
# 4     5  RA2211008020065                         MITHUN    A   A   A  A+    O
# 5     6  RA2211008020066              BHAVAHITH PRABHU M   A   A   A   O    O
# 6     7  RA2211008020067                  THIRU GOVIND V   O  A+  A+  A+    O
# 7     8  RA2211008020068                   PRITHIVIRAJ R  A+   A   A  A+   A+
# 8     9  RA2211008020069  SRI VENKATA RAMANA KRISSHANG N  B+  B+   A  A+    O
# 9    10  RA2211008020070                 VIGNESH KUMAR M  B+   C   A   A    O
# 10   11  RA2211008020071                    TAMILSELVI N   A  A+  A+   O    O
# ...

# %%
df1[['REG_NO','NAME','SGPA']].sort_values('SGPA',ascending=False)
# Out:
#              REG_NO                            NAME      SGPA
# 55  RA2211008020116                   Raghul Raaj R  9.857143
# 47  RA2211008020108                    R R AKSHAYAA  9.714286
# 43  RA2211008020104              PRINCE KUMAR SINGH  9.714286
# 36  RA2211008020097                PRIYADHARSHNEE R  9.571429
# 54  RA2211008020115                HARISH ARAVIND M  9.571429
# 21  RA2211008020082                     RAJARAJAN D  9.571429
# 33  RA2211008020094               KAVITHAVARSHINI V  9.523810
# 24  RA2211008020085                 SAMEER AHAMED A  9.476190
# 11  RA2211008020072                        YOGESH D  9.428571
# 37  RA2211008020098                   RAJESHWARAN M  9.380952
# 56  RA2211008020117                         SHYAM R  9.380952
# 18  RA2211008020079                       VISHALI S  9.380952
# 50  RA2211008020111                   REMYAA SREE S  9.333333
# 39  RA2211008020100                  PRAVIN KUMAR D  9.285714
# ...
